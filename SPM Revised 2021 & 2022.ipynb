# %% [markdown]
# **Step 1: Data for 2022**

# %%
# Loop through the worksheets and extract the data
import os
import openpyxl
from openpyxl import load_workbook

#The template file
template_workbook = openpyxl.load_workbook(r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\Template.xlsx")
ws2 = template_workbook['Sheet1']

#The master file which contains all the SPM worksheets
data_workbook  = load_workbook(r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\2022_Test.xlsx")

# Get the list of worksheet names
worksheet_names = data_workbook.sheetnames

output_folder_path = r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\2022 New"
# Create the output folder if it does not exist

for worksheet_name in worksheet_names:
    if worksheet_name.endswith('Revised'):
        ws = data_workbook[worksheet_name]
        
        # Write the data to the template sheet
        ws2.cell(row=2, column=1).value = worksheet_name
        for row in range (2,65):
            ws2.cell(row=row, column=2).value = ws['A1'].value
            ws2.cell(row=row, column=3).value = ws['B5'].value[20:27]
            ws2.cell(row=row, column=4).value = ws['A1'].value + ws['B5'].value[27: len(ws['B5'].value)]
            ws2.cell(row=row, column=8).value = 2022
        
        # Metric 1a
        (ws2.cell(row=2, column=10).value, ws2.cell(row=2, column=11).value) = (ws['H17'].value,ws['R17'].value)
        (ws2.cell(row=3, column=10).value, ws2.cell(row=3, column=11).value) = (ws['H18'].value, ws['R18'].value)
        (ws2.cell(row=4, column=10).value, ws2.cell(row=4, column=11).value)= (ws['H17'].value, ws['AL17'].value)
        (ws2.cell(row=5, column=10).value, ws2.cell(row=5, column=11).value)= (ws['H18'].value, ws['AL18'].value)
        
        # Metric 1b
        (ws2.cell(row=6, column=10).value, ws2.cell(row=6, column=11).value)= (ws['I25'].value, ws['S25'].value)
        (ws2.cell(row=7, column=10).value, ws2.cell(row=7, column=11).value)= (ws['I26'].value,ws['S26'].value)
        (ws2.cell(row=8, column=10).value, ws2.cell(row=8, column=11).value)= (ws['I25'].value, ws['AM25'].value)
        (ws2.cell(row=9, column=10).value, ws2.cell(row=9, column=11).value)= (ws['I26'].value, ws['AM26'].value)
        
        #Metric 2 - Exiters from SO
        (ws2.cell(row=10, column=10).value, ws2.cell(row=10, column=11).value)= (ws['G33'].value, ws['M33'].value)
        (ws2.cell(row=11, column=10).value, ws2.cell(row=11, column=11).value)= (ws['G33'].value, ws['V33'].value)
        (ws2.cell(row=12, column=10).value, ws2.cell(row=12, column=11).value)= (ws['G33'].value, ws['AH33'].value)
        (ws2.cell(row=13, column=10).value, ws2.cell(row=13, column=11).value)= (ws['G33'].value, ws['AS33'].value)
    
        # Metric 2 - Exiters from ES
        (ws2.cell(row=14, column=10).value, ws2.cell(row=14, column=11).value)= (ws['G34'].value, ws['M34'].value)
        (ws2.cell(row=15, column=10).value, ws2.cell(row=15, column=11).value)= (ws['G34'].value, ws['V34'].value)
        (ws2.cell(row=16, column=10).value, ws2.cell(row=16, column=11).value)= (ws['G34'].value, ws['AH34'].value)
        (ws2.cell(row=17, column=10).value, ws2.cell(row=17, column=11).value)= (ws['G34'].value, ws['AS34'].value)
        
        # Metric 2 - Exiters from TH
        (ws2.cell(row=18, column=10).value, ws2.cell(row=18, column=11).value) = (ws['G35'].value,ws['M35'].value)
        (ws2.cell(row=19, column=10).value, ws2.cell(row=19, column=11).value) = (ws['G35'].value, ws['V35'].value)
        (ws2.cell(row=20, column=10).value, ws2.cell(row=20, column=11).value) = (ws['G35'].value, ws['AH35'].value)
        (ws2.cell(row=21, column=10).value, ws2.cell(row=21, column=11).value) = (ws['G35'].value,ws['AS35'].value)
    
        # Metric 2 - Exiters from SH
        (ws2.cell(row=22, column=10).value, ws2.cell(row=22, column=11).value) = (ws['G36'].value, ws['M36'].value)
        (ws2.cell(row=23, column=10).value, ws2.cell(row=23, column=11).value) = (ws['G36'].value, ws['V36'].value)
        (ws2.cell(row=24, column=10).value, ws2.cell(row=24, column=11).value) = (ws['G36'].value, ws['AH36'].value)
        (ws2.cell(row=25, column=10).value, ws2.cell(row=25, column=11).value) = (ws['G36'].value, ws['AS36'].value)
        
        # Metric 2 - Exiters from PH
        (ws2.cell(row=26, column=10).value, ws2.cell(row=26, column=11).value) = (ws['G37'].value, ws['M37'].value)
        (ws2.cell(row=27, column=10).value, ws2.cell(row=27, column=11).value) = (ws['G37'].value, ws['V37'].value)
        (ws2.cell(row=28, column=10).value, ws2.cell(row=28, column=11).value) = (ws['G37'].value, ws['AH37'].value)
        (ws2.cell(row=29, column=10).value, ws2.cell(row=29, column=11).value) = (ws['G37'].value, ws['AS37'].value)
        
        # Metric 2 - Exiters from All
        (ws2.cell(row=30, column=10).value, ws2.cell(row=30, column=11).value) = (ws['G38'].value, ws['M38'].value)
        (ws2.cell(row=31, column=10).value, ws2.cell(row=31, column=11).value) = (ws['G38'].value, ws['V38'].value)
        (ws2.cell(row=32, column=10).value, ws2.cell(row=32, column=11).value) = (ws['G38'].value, ws['AH38'].value)
        (ws2.cell(row=33, column=10).value, ws2.cell(row=33, column=11).value) = (ws['G38'].value, ws['AS38'].value)
        
        #Metric 3a: Change in Point in Time Count
        ws2.cell(row=34, column=10).value = ws['T47'].value
        ws2.cell(row=35, column=10).value = ws['T48'].value
        ws2.cell(row=36, column=10).value = ws['T49'].value
        ws2.cell(row=37, column=10).value = ws['T50'].value
        ws2.cell(row=38, column=10).value = ws['T51'].value
        ws2.cell(row=39, column=10).value = ws['T52'].value
    
        # Metric 3b: Change in Annual Count
        ws2.cell(row=40, column=10).value = ws['AD59'].value
        ws2.cell(row=41, column=10).value = ws['AD60'].value
        ws2.cell(row=42, column=10).value = ws['AD61'].value
        ws2.cell(row=43, column=10).value = ws['AD62'].value
    
        # Measure 4: Employment and Income Growth
        (ws2.cell(row=44, column=10).value, ws2.cell(row=44, column=11).value)=(ws['AB69'].value, ws['AB70'].value) 
        (ws2.cell(row=45, column=10).value, ws2.cell(row=45, column=11).value)=(ws['AB75'].value, ws['AB76'].value)
        (ws2.cell(row=46, column=10).value, ws2.cell(row=46, column=11).value)=(ws['AB81'].value, ws['AB82'].value)
        (ws2.cell(row=47, column=10).value, ws2.cell(row=47, column=11).value)=(ws['AB88'].value, ws['AB89'].value)
        (ws2.cell(row=48, column=10).value, ws2.cell(row=48, column=11).value)=(ws['AB95'].value, ws['AB96'].value)
        (ws2.cell(row=49, column=10).value, ws2.cell(row=49, column=11).value)=(ws['AB102'].value, ws['AB103'].value)
    
    
        (ws2.cell(row=50, column=10).value, ws2.cell(row=50, column=12).value)=(ws['AB69'].value, ws['AB69'].value * 0.2) 
        (ws2.cell(row=51, column=10).value, ws2.cell(row=51, column=12).value)=(ws['AB75'].value, ws['AB75'].value * 0.54)
        ws2.cell(row=52, column=10).value = ws['AB81'].value
        (ws2.cell(row=53, column=10).value, ws2.cell(row=53, column=12).value)=(ws['AB88'].value, ws['AB88'].value * 0.2)
        (ws2.cell(row=54, column=10).value, ws2.cell(row=54, column=12).value)=(ws['AB95'].value, ws['AB95'].value * 0.54)
        ws2.cell(row=55, column=10).value = ws['AB102'].value
    
        # Measure 5: Number of Persons Homeless for the First Time
        (ws2.cell(row=56, column=10).value, ws2.cell(row=56, column=11).value)=(ws['AB111'].value,ws['AB112'].value)
        (ws2.cell(row=57, column=10).value, ws2.cell(row=57, column=11).value)=(ws['AB111'].value, ws['AB113'].value)
        (ws2.cell(row=58, column=10).value, ws2.cell(row=58, column=11).value)=(ws['AB117'].value, ws['AB118'].value)
        (ws2.cell(row=59, column=10).value, ws2.cell(row=59, column=11).value)=(ws['AB117'].value, ws['AB119'].value)

        #Measure 7: Successful Placements and PH Retention
        (ws2.cell(row=60, column=10).value, ws2.cell(row=60, column=11).value)=(ws['AB131'].value, ws['AB132'].value)
        (ws2.cell(row=61, column=10).value, ws2.cell(row=61, column=11).value)=(ws['AB131'].value, ws['AB133'].value)
        (ws2.cell(row=62, column=10).value, ws2.cell(row=62, column=11).value)=(ws['AB131'].value, ws['AB132'].value + ws['AB133'].value)
     
        (ws2.cell(row=63, column=10).value, ws2.cell(row=63, column=11).value)=(ws['AC138'].value, ws['AC139'].value)
        (ws2.cell(row=64, column=10).value, ws2.cell(row=64, column=11).value)=(ws['AB145'].value, ws['AB146'].value)
    
    elif worksheet_name.endswith("2022"):
        ws = data_workbook[worksheet_name]
        
        # Write the data to the template sheet
        ws2.cell(row=2, column=1).value = worksheet_name
        for row in range (2,65):
            ws2.cell(row=row, column=2).value = ws['A1'].value
            ws2.cell(row=row, column=3).value = ws['B5'].value[20:27]
            ws2.cell(row=row, column=4).value = ws['A1'].value + ws['B5'].value[27: len(ws['B5'].value)]
            ws2.cell(row=row, column=8).value = 2022
        
        # Metric 1a
        (ws2.cell(row=2, column=10).value, ws2.cell(row=2, column=11).value) = (ws['H17'].value,ws['N17'].value)
        (ws2.cell(row=3, column=10).value, ws2.cell(row=3, column=11).value) = (ws['H18'].value, ws['N18'].value)
        (ws2.cell(row=4, column=10).value, ws2.cell(row=4, column=11).value)= (ws['H17'].value, ws['Y17'].value)
        (ws2.cell(row=5, column=10).value, ws2.cell(row=5, column=11).value)= (ws['H18'].value, ws['Y18'].value)
        
        # Metric 1b
        (ws2.cell(row=6, column=10).value, ws2.cell(row=6, column=11).value)= (ws['I24'].value, ws['O24'].value)
        (ws2.cell(row=7, column=10).value, ws2.cell(row=7, column=11).value)= (ws['I25'].value,ws['O25'].value)
        (ws2.cell(row=8, column=10).value, ws2.cell(row=8, column=11).value)= (ws['I24'].value, ws['Z24'].value)
        (ws2.cell(row=9, column=10).value, ws2.cell(row=9, column=11).value)= (ws['I25'].value, ws['Z25'].value)
        
        #Metric 2 - Exiters from SO
        (ws2.cell(row=10, column=10).value, ws2.cell(row=10, column=11).value)= (ws['D31'].value, ws['G31'].value)
        (ws2.cell(row=11, column=10).value, ws2.cell(row=11, column=11).value)= (ws['D31'].value, ws['M31'].value)
        (ws2.cell(row=12, column=10).value, ws2.cell(row=12, column=11).value)= (ws['D31'].value, ws['X31'].value)
        (ws2.cell(row=13, column=10).value, ws2.cell(row=13, column=11).value)= (ws['D31'].value, ws['AF31'].value)
    
        # Metric 2 - Exiters from ES
        (ws2.cell(row=14, column=10).value, ws2.cell(row=14, column=11).value)= (ws['D32'].value, ws['G32'].value)
        (ws2.cell(row=15, column=10).value, ws2.cell(row=15, column=11).value)= (ws['D32'].value, ws['M32'].value)
        (ws2.cell(row=16, column=10).value, ws2.cell(row=16, column=11).value)= (ws['D32'].value, ws['X32'].value)
        (ws2.cell(row=17, column=10).value, ws2.cell(row=17, column=11).value)= (ws['D32'].value, ws['AF32'].value)
        
        # Metric 2 - Exiters from TH
        (ws2.cell(row=18, column=10).value, ws2.cell(row=18, column=11).value) = (ws['D33'].value,ws['G33'].value)
        (ws2.cell(row=19, column=10).value, ws2.cell(row=19, column=11).value) = (ws['D33'].value, ws['M33'].value)
        (ws2.cell(row=20, column=10).value, ws2.cell(row=20, column=11).value) = (ws['D33'].value, ws['X33'].value)
        (ws2.cell(row=21, column=10).value, ws2.cell(row=21, column=11).value) = (ws['D33'].value,ws['AF33'].value)
    
        # Metric 2 - Exiters from SH
        (ws2.cell(row=22, column=10).value, ws2.cell(row=22, column=11).value) = (ws['D34'].value, ws['G34'].value)
        (ws2.cell(row=23, column=10).value, ws2.cell(row=23, column=11).value) = (ws['D34'].value, ws['M34'].value)
        (ws2.cell(row=24, column=10).value, ws2.cell(row=24, column=11).value) = (ws['D34'].value, ws['X34'].value)
        (ws2.cell(row=25, column=10).value, ws2.cell(row=25, column=11).value) = (ws['D34'].value, ws['AF34'].value)
        
        # Metric 2 - Exiters from PH
        (ws2.cell(row=26, column=10).value, ws2.cell(row=26, column=11).value) = (ws['D35'].value, ws['G35'].value)
        (ws2.cell(row=27, column=10).value, ws2.cell(row=27, column=11).value) = (ws['D35'].value, ws['M35'].value)
        (ws2.cell(row=28, column=10).value, ws2.cell(row=28, column=11).value) = (ws['D35'].value, ws['X35'].value)
        (ws2.cell(row=29, column=10).value, ws2.cell(row=29, column=11).value) = (ws['D35'].value, ws['AF35'].value)
        
        # Metric 2 - Exiters from All
        (ws2.cell(row=30, column=10).value, ws2.cell(row=30, column=11).value) = (ws['D36'].value, ws['G36'].value)
        (ws2.cell(row=31, column=10).value, ws2.cell(row=31, column=11).value) = (ws['D36'].value, ws['M36'].value)
        (ws2.cell(row=32, column=10).value, ws2.cell(row=32, column=11).value) = (ws['D36'].value, ws['X36'].value)
        (ws2.cell(row=33, column=10).value, ws2.cell(row=33, column=11).value) = (ws['D36'].value, ws['AF36'].value)
        
        #Metric 3a: Change in Point in Time Count
        ws2.cell(row=34, column=10).value = ws['T45'].value
        ws2.cell(row=35, column=10).value = ws['T46'].value
        ws2.cell(row=36, column=10).value = ws['T47'].value
        ws2.cell(row=37, column=10).value = ws['T48'].value
        ws2.cell(row=38, column=10).value = ws['T49'].value
        ws2.cell(row=39, column=10).value = ws['T50'].value
    
        # Metric 3b: Change in Annual Count
        ws2.cell(row=40, column=10).value = ws['T57'].value
        ws2.cell(row=41, column=10).value = ws['T58'].value
        ws2.cell(row=42, column=10).value = ws['T59'].value
        ws2.cell(row=43, column=10).value = ws['T60'].value
    
        # Measure 4: Employment and Income Growth
        (ws2.cell(row=44, column=10).value, ws2.cell(row=44, column=11).value)=(ws['T67'].value, ws['T68'].value) 
        (ws2.cell(row=45, column=10).value, ws2.cell(row=45, column=11).value)=(ws['T73'].value, ws['T74'].value)
        (ws2.cell(row=46, column=10).value, ws2.cell(row=46, column=11).value)=(ws['T79'].value, ws['T80'].value)
        (ws2.cell(row=47, column=10).value, ws2.cell(row=47, column=11).value)=(ws['T86'].value, ws['T87'].value)
        (ws2.cell(row=48, column=10).value, ws2.cell(row=48, column=11).value)=(ws['T93'].value, ws['T94'].value)
        (ws2.cell(row=49, column=10).value, ws2.cell(row=49, column=11).value)=(ws['T100'].value, ws['T101'].value)
    
    
        (ws2.cell(row=50, column=10).value, ws2.cell(row=50, column=12).value)=(ws['T67'].value, ws['T67'].value * 0.2) 
        (ws2.cell(row=51, column=10).value, ws2.cell(row=51, column=12).value)=(ws['T73'].value, ws['T73'].value *0.54)
        ws2.cell(row=52, column=10).value = ws['T79'].value
        (ws2.cell(row=53, column=10).value, ws2.cell(row=53, column=12).value)=(ws['T86'].value, ws['T86'].value * 0.2)
        (ws2.cell(row=54, column=10).value, ws2.cell(row=54, column=12).value)=(ws['T93'].value, ws['T93'].value * 0.54)
        ws2.cell(row=55, column=10).value = ws['T100'].value
    
        # Measure 5: Number of Persons Homeless for the First Time
        (ws2.cell(row=56, column=10).value, ws2.cell(row=56, column=11).value)=(ws['T109'].value,ws['T110'].value)
        (ws2.cell(row=57, column=10).value, ws2.cell(row=57, column=11).value)=(ws['T109'].value, ws['T111'].value)
        (ws2.cell(row=58, column=10).value, ws2.cell(row=58, column=11).value)=(ws['T115'].value, ws['T116'].value)
        (ws2.cell(row=59, column=10).value, ws2.cell(row=59, column=11).value)=(ws['T115'].value, ws['T117'].value)

        #Measure 7: Successful Placements and PH Retention
        (ws2.cell(row=60, column=10).value, ws2.cell(row=60, column=11).value)=(ws['T129'].value, ws['T130'].value)
        (ws2.cell(row=61, column=10).value, ws2.cell(row=61, column=11).value)=(ws['T129'].value, ws['T131'].value)
        (ws2.cell(row=62, column=10).value, ws2.cell(row=62, column=11).value)=(ws['T129'].value, ws['T130'].value + ws['T131'].value)
     
        (ws2.cell(row=63, column=10).value, ws2.cell(row=63, column=11).value)=(ws['U136'].value, ws['U137'].value)
        (ws2.cell(row=64, column=10).value, ws2.cell(row=64, column=11).value)=(ws['T143'].value, ws['T144'].value)
     
    #Output
    output_file_path = os.path.join(output_folder_path, f"{worksheet_name}.xlsx")
    template_workbook.save(output_file_path)    


#STEP 2: Combined all the files into dataframe and calculate. 
#Remove the files in the folder, except for the final file.     
    
import pandas as pd

# Define the input and output file paths
input_folder_path = r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\2022 New"
output_file_path = r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\2022 New\2022 File for Conversion.xlsx"

# Initialize an empty list to store the dataframes
dataframes = []

# Loop through all the Excel files in the input folder
for filename in os.listdir(input_folder_path):
    if filename.endswith('.xlsx'):
        # Load the Excel file into a pandas dataframe
        filepath = os.path.join(input_folder_path, filename)
        df = pd.read_excel(filepath)
        # Append the dataframe to the list
        dataframes.append(df)        
         # Delete the input file
        os.remove(filepath)

        
# Concatenate all the dataframes into a single dataframe
concatenated_df = pd.concat(dataframes, ignore_index=True)
concatenated_df = concatenated_df.drop_duplicates()

concatenated_df['65% goal'] = concatenated_df['Universe Count'] * 0.65
concatenated_df['80% goal'] = concatenated_df['Universe Count'] * 0.8

concatenated_df['Goal Percent'] = concatenated_df['GOAL']/ concatenated_df['Universe Count']
# Create a new "Goal Percent (exits)" column and set it to empty strings
concatenated_df['Goal Percent (exits)'] = ''
concatenated_df.loc[concatenated_df['Metric'] == 'Metric 7b1: Exits from Residential Settings', 'Goal Percent (exits)'] = 0.65
concatenated_df.loc[concatenated_df['Metric'] == 'Metric 7b2: Retention of Permanent Housing', 'Goal Percent (exits)'] = 0.8
# Create a new "Number of Record" column and set it to 1 for non-duplicate rows
concatenated_df['Number of Record'] = 1
#Create New columns including From, Instructions, and State Filter
concatenated_df['From'] = 'Submitted 2022'
concatenated_df['Instructions'] = 'Add some, yo!'
concatenated_df['State Filter(optional)'] = concatenated_df['State']

duplicate_mask = concatenated_df.duplicated(keep=False)
concatenated_df.loc[duplicate_mask, 'Number of Record'] = 0

#Replace NaN with empty
concatenated_df = concatenated_df.fillna('')

#Rearrange the orders of the columns:

new_order = ['Unnamed: 0', 'CoC', 'CoCName', 'From', 'Indicator', 'Instructions', 'Measure', 'Metric', 'Reporting Year', 'State',  'State Filter(optional)','Target Group', '65% goal', '80% goal', 'GOAL','Goal Percent', 'Goal Percent (exits)', 'Number of Record', 'Outcome | Count','Universe Count']
concatenated_df = concatenated_df.reindex(columns=new_order)

concatenated_df.head()     

# Write the concatenated dataframe to an Excel file
concatenated_df.to_excel(output_file_path, index=False)

# %% [markdown]
# **PART 2: Get the data for Revised 2021**

# %%
import os
import openpyxl
from openpyxl import load_workbook

#The template file
template_workbook = openpyxl.load_workbook(r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\Template.xlsx")
ws2 = template_workbook['Sheet1']

#The master file which contains all the SPM worksheets
data_workbook  = load_workbook(r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\2022_Test.xlsx")

# Get the list of worksheet names
worksheet_names = data_workbook.sheetnames

output_folder_path = r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\2021 Revised"
# Create the output folder if it does not exist

for worksheet_name in worksheet_names:
    if worksheet_name.endswith('Revised'):
        ws = data_workbook[worksheet_name]
        
        # Write the data to the template sheet
        ws2.cell(row=2, column=1).value = worksheet_name
        for row in range (2,65):
            ws2.cell(row=row, column=2).value = ws['A1'].value
            ws2.cell(row=row, column=3).value = ws['B5'].value[20:27]
            ws2.cell(row=row, column=4).value = ws['A1'].value + ws['B5'].value[27: len(ws['B5'].value)]
            ws2.cell(row=row, column=8).value = 2021
        
        # Metric 1a
        (ws2.cell(row=2, column=10).value, ws2.cell(row=2, column=11).value) = (ws['E17'].value,ws['N17'].value)
        (ws2.cell(row=3, column=10).value, ws2.cell(row=3, column=11).value) = (ws['E18'].value, ws['N18'].value)
        (ws2.cell(row=4, column=10).value, ws2.cell(row=4, column=11).value)= (ws['E17'].value, ws['AF17'].value)
        (ws2.cell(row=5, column=10).value, ws2.cell(row=5, column=11).value)= (ws['E18'].value, ws['AF18'].value)
        
        # Metric 1b
        (ws2.cell(row=6, column=10).value, ws2.cell(row=6, column=11).value)= (ws['F25'].value, ws['O25'].value)
        (ws2.cell(row=7, column=10).value, ws2.cell(row=7, column=11).value)= (ws['F26'].value,ws['O26'].value)
        (ws2.cell(row=8, column=10).value, ws2.cell(row=8, column=11).value)= (ws['F25'].value, ws['AG25'].value)
        (ws2.cell(row=9, column=10).value, ws2.cell(row=9, column=11).value)= (ws['F26'].value, ws['AG26'].value)
        
        #Metric 2 - Exiters from SO
        (ws2.cell(row=10, column=10).value, ws2.cell(row=10, column=11).value)= (ws['D33'].value, ws['J33'].value)
        (ws2.cell(row=11, column=10).value, ws2.cell(row=11, column=11).value)= (ws['D33'].value, ws['R33'].value)
        (ws2.cell(row=12, column=10).value, ws2.cell(row=12, column=11).value)= (ws['D33'].value, ws['AE33'].value)
        (ws2.cell(row=13, column=10).value, ws2.cell(row=13, column=11).value)= (ws['D33'].value, ws['J33'].value +ws['R33'].value +ws['AE33'].value)
    
        # Metric 2 - Exiters from ES
        (ws2.cell(row=14, column=10).value, ws2.cell(row=14, column=11).value)= (ws['D34'].value, ws['J34'].value)
        (ws2.cell(row=15, column=10).value, ws2.cell(row=15, column=11).value)= (ws['D34'].value, ws['R34'].value)
        (ws2.cell(row=16, column=10).value, ws2.cell(row=16, column=11).value)= (ws['D34'].value, ws['AE34'].value)
        (ws2.cell(row=17, column=10).value, ws2.cell(row=17, column=11).value)= (ws['D34'].value, ws['J34'].value + ws['R34'].value + ws['AE34'].value)
        
        # Metric 2 - Exiters from TH
        (ws2.cell(row=18, column=10).value, ws2.cell(row=18, column=11).value) = (ws['D35'].value, ws['J35'].value)
        (ws2.cell(row=19, column=10).value, ws2.cell(row=19, column=11).value) = (ws['D35'].value, ws['R35'].value)
        (ws2.cell(row=20, column=10).value, ws2.cell(row=20, column=11).value) = (ws['D35'].value, ws['AE35'].value)
        (ws2.cell(row=21, column=10).value, ws2.cell(row=21, column=11).value) = (ws['D35'].value, ws['J35'].value + ws['R35'].value + ws['AE35'].value)
    
        # Metric 2 - Exiters from SH
        (ws2.cell(row=22, column=10).value, ws2.cell(row=22, column=11).value) = (ws['D36'].value, ws['J36'].value)
        (ws2.cell(row=23, column=10).value, ws2.cell(row=23, column=11).value) = (ws['D36'].value, ws['R36'].value)
        (ws2.cell(row=24, column=10).value, ws2.cell(row=24, column=11).value) = (ws['D36'].value, ws['AE36'].value)
        (ws2.cell(row=25, column=10).value, ws2.cell(row=25, column=11).value) = (ws['D36'].value, ws['J36'].value + ws['R36'].value + ws['AE36'].value)
        
        # Metric 2 - Exiters from PH
        (ws2.cell(row=26, column=10).value, ws2.cell(row=26, column=11).value) = (ws['D37'].value, ws['J37'].value)
        (ws2.cell(row=27, column=10).value, ws2.cell(row=27, column=11).value) = (ws['D37'].value, ws['R37'].value)
        (ws2.cell(row=28, column=10).value, ws2.cell(row=28, column=11).value) = (ws['D37'].value, ws['AE37'].value)
        (ws2.cell(row=29, column=10).value, ws2.cell(row=29, column=11).value) = (ws['D37'].value, ws['J37'].value + ws['R37'].value + ws['AE37'].value)
        
        # Metric 2 - Exiters from All
        (ws2.cell(row=30, column=10).value, ws2.cell(row=30, column=11).value) = (ws['D38'].value, ws['J38'].value)
        (ws2.cell(row=31, column=10).value, ws2.cell(row=31, column=11).value) = (ws['D38'].value, ws['R38'].value)
        (ws2.cell(row=32, column=10).value, ws2.cell(row=32, column=11).value) = (ws['D38'].value, ws['AE38'].value)
        (ws2.cell(row=33, column=10).value, ws2.cell(row=33, column=11).value) = (ws['D38'].value, ws['J38'].value + ws['R38'].value + ws['AE38'].value)
        
        #Metric 3a: Change in Point in Time Count
        ws2.cell(row=34, column=10).value = ws['P47'].value
        ws2.cell(row=35, column=10).value = ws['P48'].value
        ws2.cell(row=36, column=10).value = ws['P49'].value
        ws2.cell(row=37, column=10).value = ws['P50'].value
        ws2.cell(row=38, column=10).value = ws['P51'].value
        ws2.cell(row=39, column=10).value = ws['P52'].value
    
        # Metric 3b: Change in Annual Count
        ws2.cell(row=40, column=10).value = ws['T59'].value
        ws2.cell(row=41, column=10).value = ws['T60'].value
        ws2.cell(row=42, column=10).value = ws['T61'].value
        ws2.cell(row=43, column=10).value = ws['T62'].value
    
        # Measure 4: Employment and Income Growth
        (ws2.cell(row=44, column=10).value, ws2.cell(row=44, column=11).value)=(ws['T69'].value, ws['T70'].value) 
        (ws2.cell(row=45, column=10).value, ws2.cell(row=45, column=11).value)=(ws['T75'].value, ws['T76'].value)
        (ws2.cell(row=46, column=10).value, ws2.cell(row=46, column=11).value)=(ws['T81'].value, ws['T82'].value)
        (ws2.cell(row=47, column=10).value, ws2.cell(row=47, column=11).value)=(ws['T88'].value, ws['T89'].value)
        (ws2.cell(row=48, column=10).value, ws2.cell(row=48, column=11).value)=(ws['T95'].value, ws['T96'].value)
        (ws2.cell(row=49, column=10).value, ws2.cell(row=49, column=11).value)=(ws['T102'].value, ws['T103'].value)
    
    
        (ws2.cell(row=50, column=10).value, ws2.cell(row=50, column=12).value)=(ws['T69'].value, ws['T69'].value * 0.2) 
        (ws2.cell(row=51, column=10).value, ws2.cell(row=51, column=12).value)=(ws['T75'].value, ws['T75'].value * 0.54)
        ws2.cell(row=52, column=10).value = ws['T81'].value
        (ws2.cell(row=53, column=10).value, ws2.cell(row=53, column=12).value)=(ws['T88'].value, ws['T88'].value * 0.2)
        (ws2.cell(row=54, column=10).value, ws2.cell(row=54, column=12).value)=(ws['T95'].value, ws['T95'].value * 0.54)
        ws2.cell(row=55, column=10).value = ws['T102'].value
    
        # Measure 5: Number of Persons Homeless for the First Time
        (ws2.cell(row=56, column=10).value, ws2.cell(row=56, column=11).value)=(ws['T111'].value,ws['T112'].value)
        (ws2.cell(row=57, column=10).value, ws2.cell(row=57, column=11).value)=(ws['T111'].value, ws['T113'].value)
        (ws2.cell(row=58, column=10).value, ws2.cell(row=58, column=11).value)=(ws['T117'].value, ws['T118'].value)
        (ws2.cell(row=59, column=10).value, ws2.cell(row=59, column=11).value)=(ws['T117'].value, ws['T119'].value)

        #Measure 7: Successful Placements and PH Retention
        (ws2.cell(row=60, column=10).value, ws2.cell(row=60, column=11).value)=(ws['T131'].value, ws['T132'].value)
        (ws2.cell(row=61, column=10).value, ws2.cell(row=61, column=11).value)=(ws['T131'].value, ws['T133'].value)
        (ws2.cell(row=62, column=10).value, ws2.cell(row=62, column=11).value)=(ws['T131'].value, ws['T132'].value + ws['T133'].value)
     
        (ws2.cell(row=63, column=10).value, ws2.cell(row=63, column=11).value)=(ws['U138'].value, ws['U139'].value)
        (ws2.cell(row=64, column=10).value, ws2.cell(row=64, column=11).value)=(ws['T145'].value, ws['T146'].value)
        
    output_file_path = os.path.join(output_folder_path, f"{worksheet_name}.xlsx")
    template_workbook.save(output_file_path)  
    
    
# STEP 2: Combine all the files into a dataframe and do the calculation. 

import pandas as pd

# Define the input and output file paths
input_folder_path = r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\2021 Revised"
output_file_path = r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\2021 Revised\2021 File for Conversion.xlsx"

# Initialize an empty list to store the dataframes
dataframes = []

# Loop through all the Excel files in the input folder
for filename in os.listdir(input_folder_path):
    if filename.endswith('.xlsx'):
        # Load the Excel file into a pandas dataframe
        filepath = os.path.join(input_folder_path, filename)
        df = pd.read_excel(filepath)
        # Append the dataframe to the list
        dataframes.append(df)
        # Delete the input file
        os.remove(filepath)

# Concatenate all the dataframes into a single dataframe
concatenated_df = pd.concat(dataframes, ignore_index=True)
concatenated_df = concatenated_df.drop_duplicates()

concatenated_df['65% goal'] = concatenated_df['Universe Count'] * 0.65
concatenated_df['80% goal'] = concatenated_df['Universe Count'] * 0.8

concatenated_df['Goal Percent'] = concatenated_df['GOAL']/ concatenated_df['Universe Count']
# Create a new "Goal Percent (exits)" column and set it to empty strings
concatenated_df['Goal Percent (exits)'] = ''
concatenated_df.loc[concatenated_df['Metric'] == 'Metric 7b1: Exits from Residential Settings', 'Goal Percent (exits)'] = '0.65'
concatenated_df.loc[concatenated_df['Metric'] == 'Metric 7b2: Retention of Permanent Housing', 'Goal Percent (exits)'] = '0.8'
# Create a new "Number of Record" column and set it to 1 for non-duplicate rows
concatenated_df['Number of Record'] = 1
#Create New columns including From, Instructions, and State Filter
concatenated_df['From'] = 'Submitted 2022'
concatenated_df['Instructions'] = 'Add some, yo!'
concatenated_df['State Filter(optional)'] = concatenated_df['State']

duplicate_mask = concatenated_df.duplicated(keep=False)
concatenated_df.loc[duplicate_mask, 'Number of Record'] = 0

#Replace NaN with empty
concatenated_df = concatenated_df.fillna('')

#Rearrange the orders of the columns:

new_order = ['Unnamed: 0', 'CoC', 'CoCName', 'From', 'Indicator', 'Instructions', 'Measure', 'Metric', 'Reporting Year', 'State',  'State Filter(optional)','Target Group', '65% goal', '80% goal', 'GOAL','Goal Percent', 'Goal Percent (exits)', 'Number of Record', 'Outcome | Count','Universe Count']
concatenated_df = concatenated_df.reindex(columns=new_order)

concatenated_df.head()     

# Write the concatenated dataframe to an Excel file
concatenated_df.to_excel(output_file_path, index=False)

# %% [markdown]
# **Step 3: Get the data for 2021 IF NOT RESUBMITTED**

# %%
# Loop through the worksheets and extract the data
import os
import openpyxl
from openpyxl import load_workbook

#The template file
template_workbook = openpyxl.load_workbook(r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\Template.xlsx")
ws2 = template_workbook['Sheet1']

#The master file which contains all the SPM worksheets
data_workbook  = load_workbook(r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\Data\2021\2021.xlsx")

# Get the list of worksheet names
worksheet_names = data_workbook.sheetnames

output_folder_path = r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\2021 Revised"
# Create the output folder if it does not exist

for worksheet_name in worksheet_names:
    if worksheet_name.endswith('2021'):
        ws = data_workbook[worksheet_name]
        
        # Write the data to the template sheet
        ws2.cell(row=2, column=1).value = worksheet_name
        for row in range (2,65):
            ws2.cell(row=row, column=2).value = ws['A1'].value
            ws2.cell(row=row, column=3).value = ws['B5'].value[20:27]
            ws2.cell(row=row, column=4).value = ws['A1'].value + ws['B5'].value[27: len(ws['B5'].value)]
            ws2.cell(row=row, column=8).value = 2020
        
         # Metric 1a
        (ws2.cell(row=2, column=10).value, ws2.cell(row=2, column=11).value) = (ws['H17'].value,ws['N17'].value)
        (ws2.cell(row=3, column=10).value, ws2.cell(row=3, column=11).value) = (ws['H18'].value, ws['N18'].value)
        (ws2.cell(row=4, column=10).value, ws2.cell(row=4, column=11).value)= (ws['H17'].value, ws['Y17'].value)
        (ws2.cell(row=5, column=10).value, ws2.cell(row=5, column=11).value)= (ws['H18'].value, ws['Y18'].value)
        
        # Metric 1b
        (ws2.cell(row=6, column=10).value, ws2.cell(row=6, column=11).value)= (ws['I24'].value, ws['O24'].value)
        (ws2.cell(row=7, column=10).value, ws2.cell(row=7, column=11).value)= (ws['I25'].value,ws['O25'].value)
        (ws2.cell(row=8, column=10).value, ws2.cell(row=8, column=11).value)= (ws['I24'].value, ws['Z24'].value)
        (ws2.cell(row=9, column=10).value, ws2.cell(row=9, column=11).value)= (ws['I25'].value, ws['Z25'].value)
        
        #Metric 2 - Exiters from SO
        (ws2.cell(row=10, column=10).value, ws2.cell(row=10, column=11).value)= (ws['D31'].value, ws['G31'].value)
        (ws2.cell(row=11, column=10).value, ws2.cell(row=11, column=11).value)= (ws['D31'].value, ws['M31'].value)
        (ws2.cell(row=12, column=10).value, ws2.cell(row=12, column=11).value)= (ws['D31'].value, ws['X31'].value)
        (ws2.cell(row=13, column=10).value, ws2.cell(row=13, column=11).value)= (ws['D31'].value, ws['AF31'].value)
    
        # Metric 2 - Exiters from ES
        (ws2.cell(row=14, column=10).value, ws2.cell(row=14, column=11).value)= (ws['D32'].value, ws['G32'].value)
        (ws2.cell(row=15, column=10).value, ws2.cell(row=15, column=11).value)= (ws['D32'].value, ws['M32'].value)
        (ws2.cell(row=16, column=10).value, ws2.cell(row=16, column=11).value)= (ws['D32'].value, ws['X32'].value)
        (ws2.cell(row=17, column=10).value, ws2.cell(row=17, column=11).value)= (ws['D32'].value, ws['AF32'].value)
        
        # Metric 2 - Exiters from TH
        (ws2.cell(row=18, column=10).value, ws2.cell(row=18, column=11).value) = (ws['D33'].value,ws['G33'].value)
        (ws2.cell(row=19, column=10).value, ws2.cell(row=19, column=11).value) = (ws['D33'].value, ws['M33'].value)
        (ws2.cell(row=20, column=10).value, ws2.cell(row=20, column=11).value) = (ws['D33'].value, ws['X33'].value)
        (ws2.cell(row=21, column=10).value, ws2.cell(row=21, column=11).value) = (ws['D33'].value,ws['AF33'].value)
    
        # Metric 2 - Exiters from SH
        (ws2.cell(row=22, column=10).value, ws2.cell(row=22, column=11).value) = (ws['D34'].value, ws['G34'].value)
        (ws2.cell(row=23, column=10).value, ws2.cell(row=23, column=11).value) = (ws['D34'].value, ws['M34'].value)
        (ws2.cell(row=24, column=10).value, ws2.cell(row=24, column=11).value) = (ws['D34'].value, ws['X34'].value)
        (ws2.cell(row=25, column=10).value, ws2.cell(row=25, column=11).value) = (ws['D34'].value, ws['AF34'].value)
        
        # Metric 2 - Exiters from PH
        (ws2.cell(row=26, column=10).value, ws2.cell(row=26, column=11).value) = (ws['D35'].value, ws['G35'].value)
        (ws2.cell(row=27, column=10).value, ws2.cell(row=27, column=11).value) = (ws['D35'].value, ws['M35'].value)
        (ws2.cell(row=28, column=10).value, ws2.cell(row=28, column=11).value) = (ws['D35'].value, ws['X35'].value)
        (ws2.cell(row=29, column=10).value, ws2.cell(row=29, column=11).value) = (ws['D35'].value, ws['AF35'].value)
        
        # Metric 2 - Exiters from All
        (ws2.cell(row=30, column=10).value, ws2.cell(row=30, column=11).value) = (ws['D36'].value, ws['G36'].value)
        (ws2.cell(row=31, column=10).value, ws2.cell(row=31, column=11).value) = (ws['D36'].value, ws['M36'].value)
        (ws2.cell(row=32, column=10).value, ws2.cell(row=32, column=11).value) = (ws['D36'].value, ws['X36'].value)
        (ws2.cell(row=33, column=10).value, ws2.cell(row=33, column=11).value) = (ws['D36'].value, ws['AF36'].value)
        
        #Metric 3a: Change in Point in Time Count
        ws2.cell(row=34, column=10).value = ws['T45'].value
        ws2.cell(row=35, column=10).value = ws['T46'].value
        ws2.cell(row=36, column=10).value = ws['T47'].value
        ws2.cell(row=37, column=10).value = ws['T48'].value
        ws2.cell(row=38, column=10).value = ws['T49'].value
        ws2.cell(row=39, column=10).value = ws['T50'].value
    
        # Metric 3b: Change in Annual Count
        ws2.cell(row=40, column=10).value = ws['T57'].value
        ws2.cell(row=41, column=10).value = ws['T58'].value
        ws2.cell(row=42, column=10).value = ws['T59'].value
        ws2.cell(row=43, column=10).value = ws['T60'].value
    
        # Measure 4: Employment and Income Growth
        (ws2.cell(row=44, column=10).value, ws2.cell(row=44, column=11).value)=(ws['T67'].value, ws['T68'].value) 
        (ws2.cell(row=45, column=10).value, ws2.cell(row=45, column=11).value)=(ws['T73'].value, ws['T74'].value)
        (ws2.cell(row=46, column=10).value, ws2.cell(row=46, column=11).value)=(ws['T79'].value, ws['T80'].value)
        (ws2.cell(row=47, column=10).value, ws2.cell(row=47, column=11).value)=(ws['T86'].value, ws['T87'].value)
        (ws2.cell(row=48, column=10).value, ws2.cell(row=48, column=11).value)=(ws['T93'].value, ws['T94'].value)
        (ws2.cell(row=49, column=10).value, ws2.cell(row=49, column=11).value)=(ws['T100'].value, ws['T101'].value)
    
    
        (ws2.cell(row=50, column=10).value, ws2.cell(row=50, column=12).value)=(ws['T67'].value, ws['T67'].value * 0.2) 
        (ws2.cell(row=51, column=10).value, ws2.cell(row=51, column=12).value)=(ws['T73'].value, ws['T73'].value *0.54)
        ws2.cell(row=52, column=10).value = ws['T79'].value
        (ws2.cell(row=53, column=10).value, ws2.cell(row=53, column=12).value)=(ws['T86'].value, ws['T86'].value * 0.2)
        (ws2.cell(row=54, column=10).value, ws2.cell(row=54, column=12).value)=(ws['T93'].value, ws['T93'].value * 0.54)
        ws2.cell(row=55, column=10).value = ws['T100'].value
    
        # Measure 5: Number of Persons Homeless for the First Time
        (ws2.cell(row=56, column=10).value, ws2.cell(row=56, column=11).value)=(ws['T109'].value,ws['T110'].value)
        (ws2.cell(row=57, column=10).value, ws2.cell(row=57, column=11).value)=(ws['T109'].value, ws['T111'].value)
        (ws2.cell(row=58, column=10).value, ws2.cell(row=58, column=11).value)=(ws['T115'].value, ws['T116'].value)
        (ws2.cell(row=59, column=10).value, ws2.cell(row=59, column=11).value)=(ws['T115'].value, ws['T117'].value)

        #Measure 7: Successful Placements and PH Retention
        (ws2.cell(row=60, column=10).value, ws2.cell(row=60, column=11).value)=(ws['T129'].value, ws['T130'].value)
        (ws2.cell(row=61, column=10).value, ws2.cell(row=61, column=11).value)=(ws['T129'].value, ws['T131'].value)
        (ws2.cell(row=62, column=10).value, ws2.cell(row=62, column=11).value)=(ws['T129'].value, ws['T130'].value + ws['T131'].value)
     
        (ws2.cell(row=63, column=10).value, ws2.cell(row=63, column=11).value)=(ws['U136'].value, ws['U137'].value)
        (ws2.cell(row=64, column=10).value, ws2.cell(row=64, column=11).value)=(ws['T143'].value, ws['T144'].value)
    #Output
    output_file_path = os.path.join(output_folder_path, f"{worksheet_name}.xlsx")
    template_workbook.save(output_file_path)    


#STEP 2: Combined all the files into dataframe and calculate. 
#Remove the files in the folder, except for the final file.     
    
import pandas as pd

# Define the input and output file paths
input_folder_path = r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\2021 Revised"
output_file_path = r"C:\Users\Thu Le\Documents\Documents\System Performance Measures\2021 Revised\2021 Not Revised File.xlsx"

# Initialize an empty list to store the dataframes
dataframes = []

# Loop through all the Excel files in the input folder
for filename in os.listdir(input_folder_path):
    if filename.endswith('.xlsx'):
        # Load the Excel file into a pandas dataframe
        filepath = os.path.join(input_folder_path, filename)
        df = pd.read_excel(filepath)
        # Append the dataframe to the list
        dataframes.append(df)        
         # Delete the input file
        os.remove(filepath)

        
# Concatenate all the dataframes into a single dataframe
concatenated_df = pd.concat(dataframes, ignore_index=True)
concatenated_df = concatenated_df.drop_duplicates()

concatenated_df['65% goal'] = concatenated_df['Universe Count'] * 0.65
concatenated_df['80% goal'] = concatenated_df['Universe Count'] * 0.8

concatenated_df['Goal Percent'] = concatenated_df['GOAL']/ concatenated_df['Universe Count']
# Create a new "Goal Percent (exits)" column and set it to empty strings
concatenated_df['Goal Percent (exits)'] = ''
concatenated_df.loc[concatenated_df['Metric'] == 'Metric 7b1: Exits from Residential Settings', 'Goal Percent (exits)'] = 0.65
concatenated_df.loc[concatenated_df['Metric'] == 'Metric 7b2: Retention of Permanent Housing', 'Goal Percent (exits)'] = 0.8
# Create a new "Number of Record" column and set it to 1 for non-duplicate rows
concatenated_df['Number of Record'] = 1
#Create New columns including From, Instructions, and State Filter
concatenated_df['From'] = 'Submitted 2021'
concatenated_df['Instructions'] = 'Add some, yo!'
concatenated_df['State Filter(optional)'] = concatenated_df['State']

duplicate_mask = concatenated_df.duplicated(keep=False)
concatenated_df.loc[duplicate_mask, 'Number of Record'] = 0

#Replace NaN with empty
concatenated_df = concatenated_df.fillna('')

#Rearrange the orders of the columns:

new_order = ['Unnamed: 0', 'CoC', 'CoCName', 'From', 'Indicator', 'Instructions', 'Measure', 'Metric', 'Reporting Year', 'State',  'State Filter(optional)','Target Group', '65% goal', '80% goal', 'GOAL','Goal Percent', 'Goal Percent (exits)', 'Number of Record', 'Outcome | Count','Universe Count']
concatenated_df = concatenated_df.reindex(columns=new_order)

concatenated_df.head()     

# Write the concatenated dataframe to an Excel file
concatenated_df.to_excel(output_file_path, index=False)
