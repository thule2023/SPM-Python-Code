# %%
import os
import openpyxl
from openpyxl import load_workbook

#The template file


#The master file which contains all the SPM worksheets
data_workbook  = load_workbook(r"C:\Users\Thu Le\Documents\Documents\SPM\2019 HUD Data.xlsx")
ws = data_workbook.active  # Assuming the data is present in the active sheet of the master workbook

# Get the last row with data in the worksheet
output_folder_path = r"C:\Users\Thu Le\Documents\Documents\SPM\2019"

# Get the list of CoCs from the first row of the data worksheet
coc_list = list(ws.iter_rows(min_row=1, max_row=1, values_only=True))[0][1:]
os.makedirs(output_folder_path, exist_ok=True)

# Create the output folder if it does not exist
for row in range(2, ws.max_row + 1):
    
    template_workbook = openpyxl.load_workbook(r"C:\Users\Thu Le\Documents\Documents\SPM\Template_Metric2.xlsx")
    ws2 = template_workbook['Sheet1']
    
    # Get the name of the current worksheet (assuming worksheet_name should be set to this)
    worksheet_name = ws.cell(row=row, column=39).value
    
    ws2.cell(row=2, column=2).value = ws.cell(row=row, column=39).value #name of the worksheet    
    ws2.cell(row=2, column=19).value = ws.cell(row=row, column= 28).value
    ws2.cell(row=2, column=20).value = ws.cell(row=row, column=16).value
    ws2.cell(row=3, column=19).value = ws.cell(row=row, column= 18).value - ws.cell(row=row, column= 28).value
    ws2.cell(row=3, column=20).value = ws.cell(row=row, column=16).value
    ws2.cell(row=4, column=20).value = ws.cell(row=row, column=16).value
    ws2.cell(row=4, column=19).value = ws.cell(row=row, column=23).value - ws.cell(row=row, column= 18).value
    ws2.cell(row=5, column=20).value = ws.cell(row=row, column=16).value
    ws2.cell(row=5, column=19).value = ws.cell(row=row, column=23).value
    
    ws2.cell(row=6, column=19).value = ws.cell(row=row, column= 29).value
    ws2.cell(row=6, column=20).value = ws.cell(row=row, column=13).value
    ws2.cell(row=7, column=20).value = ws.cell(row=row, column=13).value
    ws2.cell(row=7, column=19).value = ws.cell(row=row, column=19).value - ws.cell(row=row, column= 29).value
    ws2.cell(row=8, column=20).value = ws.cell(row=row, column=13).value
    ws2.cell(row=8, column=19).value = ws.cell(row=row, column=24).value - ws.cell(row=row, column=19).value
    ws2.cell(row=9, column=20).value = ws.cell(row=row, column=13).value
    ws2.cell(row=9, column=19).value = ws.cell(row=row, column=24).value
    
    ws2.cell(row=10, column=19).value = ws.cell(row=row, column=30).value
    ws2.cell(row=10, column=20).value = ws.cell(row=row, column=17).value
    ws2.cell(row=11, column=20).value = ws.cell(row=row, column=17).value
    ws2.cell(row=11, column=19).value = ws.cell(row=row, column=20).value - ws.cell(row=row, column=30).value
    ws2.cell(row=12, column=20).value = ws.cell(row=row, column=17).value
    ws2.cell(row=12, column=19).value = ws.cell(row=row, column=25).value - ws.cell(row=row, column=20).value
    ws2.cell(row=13, column=20).value = ws.cell(row=row, column=17).value
    ws2.cell(row=13, column=19).value = ws.cell(row=row, column=25).value
    
    ws2.cell(row=14, column=19).value = ws.cell(row=row, column=31).value
    ws2.cell(row=14, column=20).value = ws.cell(row=row, column=15).value
    ws2.cell(row=15, column=20).value = ws.cell(row=row, column=15).value
    ws2.cell(row=15, column=19).value = ws.cell(row=row, column=21).value - ws.cell(row=row, column=31).value
    ws2.cell(row=16, column=20).value = ws.cell(row=row, column=15).value
    ws2.cell(row=16, column=19).value = ws.cell(row=row, column=26).value - ws.cell(row=row, column=21).value
    ws2.cell(row=17, column=20).value = ws.cell(row=row, column=15).value
    ws2.cell(row=17, column=19).value = ws.cell(row=row, column=26).value
    
    ws2.cell(row=18, column=19).value = ws.cell(row=row, column=32).value
    ws2.cell(row=18, column=20).value = ws.cell(row=row, column=14).value
    ws2.cell(row=19, column=20).value = ws.cell(row=row, column=14).value
    ws2.cell(row=19, column=19).value = ws.cell(row=row, column=22).value - ws.cell(row=row, column=32).value
    ws2.cell(row=20, column=20).value = ws.cell(row=row, column=14).value
    ws2.cell(row=20, column=19).value = ws.cell(row=row, column=27).value - ws.cell(row=row, column=22).value
    ws2.cell(row=21, column=20).value = ws.cell(row=row, column=14).value
    ws2.cell(row=21, column=19).value = ws.cell(row=row, column=27).value
    
    ws2.cell(row=22, column=19).value = ws.cell(row=row, column=60).value
    ws2.cell(row=22, column=20).value = ws.cell(row=row, column=58).value
    ws2.cell(row=23, column=20).value = ws.cell(row=row, column=58).value
    ws2.cell(row=23, column=19).value = ws2.cell(row=3, column=19).value + ws2.cell(row=7, column=19).value + ws2.cell(row=11, column=19).value + ws2.cell(row=15, column=19).value + ws2.cell(row=19, column=19).value
    ws2.cell(row=24, column=20).value = ws.cell(row=row, column=58).value
    ws2.cell(row=24, column=19).value = ws2.cell(row=4, column=19).value + ws2.cell(row=8, column=19).value + ws2.cell(row=12, column=19).value + ws2.cell(row=16, column=19).value + ws2.cell(row=20, column=19).value
    ws2.cell(row=25, column=19).value = ws.cell(row=row, column=59).value
    ws2.cell(row=25, column=20).value = ws.cell(row=row, column=58).value 
    
    
    # Save the template workbook as a new file for each CoC
    output_file_path = os.path.join(output_folder_path, f"{worksheet_name}.xlsx")
    template_workbook.save(output_file_path)
